# %%
import os 
from flask import Flask

# %%
from app import db, app, Email, WordList

# %%
app.app_context().push()

# %%
db.create_all()

# %%
db.session.bulk_insert_mappings??

# %%
db.session.bulk_save_objects??

# %%
import pandas as pd

# %%
base_dir = "F:\Breaches\Email"

# %%
files = os.listdir(base_dir)

# %%
df1 = pd.read_excel(os.path.join(base_dir,files[0]), header=0)

# %%
df1.columns
# Out:
# Index(['E-mail address', 'Owner's name', 'Location'], dtype='object')

# %%
df1.columns = ["email", "name", "location"]

# %%
df1
# Out:
#                                  email name  \
# 0              info@bharathlisting.com  NaN
# 1                 miya.khan9@gmail.com  NaN
# 2           kirankumarjain21@gmail.com  NaN
# 3           harsit982445.gsm@gmail.com  NaN
# 4                 rupesh@smsidea.co.in  NaN
# ...                                ...  ...
# 15531          info@bharathlisting.com  NaN
# 15532             loharuagro@gmail.com  NaN
# 15533          info@bharathlisting.com  NaN
# 15534  manmohandecor@tradepassport.org  NaN
# 15535          info@bharathlisting.com  NaN
#
#                                                 location
# 0                         http://www.bharathlisting.com/
# 1      http://www.bharathlisting.com/category/4/adver...
# 2      http://www.bharathlisting.com/category/4/adver...
# 3      http://www.bharathlisting.com/category/4/adver...
# 4      http://www.bharathlisting.com/category/4/adver...
# ...                                                  ...
# ...

# %%
emails = [Email(email = mail) for mail in df1["email"]]

# %%
[db.session.add(email) for email in emails]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
Email.query.limit(10).all()
# Out:
# [<Email info@bharathlisting.com>,
#  <Email info@bharathlisting.com>,
#  <Email miya.khan9@gmail.com>,
#  <Email kirankumarjain21@gmail.com>,
#  <Email harsit982445.gsm@gmail.com>,
#  <Email rupesh@smsidea.co.in>,
#  <Email admin@wavetechads.in>,
#  <Email contact@99beststores.com>,
#  <Email tinfo.a117@gmail.com>,
#  <Email info@boomadcom.com>]

# %%
db.session.commit()

# %%
for i in df1["email"]:
    print(str(i))  
    break
# Out:
# info@bharathlisting.com

# %%
df2 = pd.read_excel(os.path.join(base_dir,files[1]), header = 0)

# %%
df2.columns = ["email", "name", "location"]

# %%
emails = [Email(email=mail) for mail in df2["email"]]

# %%
[db.session.add(mail) for mail in emails]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
db.session.commit()

# %%
Email.query.count()
# Out:
# 16140

# %%
from app import Phone

# %%
phone_dir = "F:\Breaches\Phone"

# %%
files = os.listdir(phone_dir)

# %%
pdf = pd.read_excel(os.path.join(phone_dir, files[2]), header = 0)

# %%
pdf.shape
# Out:
# (1048574, 4)

# %%
pdf.dtypes
# Out:
# Name                object
# Gender              object
# Mobile               int64
# Current Location    object
# dtype: object

# %%
pdf.head()
# Out:
#               Name Gender      Mobile Current Location
# 0    Mayunk Saxena   Male  9850358101            Delhi
# 1  SUDHAKAR SHETTY   Male  9850357958        Faridabad
# 2      Mrpssolanki   Male  9850357951            Delhi
# 3     Mrsanjaypal.   Male  9850357733            Delhi
# 4       Mrshivram.   Male  9850357688            Delhi

# %%
pdf.dropna(subset = ["Name"], inplace = True)

# %%
pdf.isna().sum()
# Out:
# Name                    0
# Gender                 80
# Mobile                  0
# Current Location    71102
# dtype: int64

# %%
pdf.dtypes
# Out:
# Name                object
# Gender              object
# Mobile               int64
# Current Location    object
# dtype: object

# %%
phones = [Phone(number = int(pdf.iloc[i]["Mobile"]), name = pdf.iloc[i]["Name"]) for i in range(pdf.shape[0])]

# %%
len(phones)
# Out:
# 1048574

# %%
phones
# Out:
# [<Phone 9850358101 - Mayunk Saxena>,
#  <Phone 9850357958 - SUDHAKAR SHETTY>,
#  <Phone 9850357951 - Mrpssolanki>,
#  <Phone 9850357733 - Mrsanjaypal.>,
#  <Phone 9850357688 - Mrshivram.>,
#  <Phone 9850357640 - MrTUNTUN.PANDIT>,
#  <Phone 9850357583 - MrKAMLESH KUMAR SHARMA..>,
#  <Phone 9850357494 - MrPHOOL CHAND..>,
#  <Phone 9850357404 - MrsPRJNASHETTY>,
#  <Phone 9850356961 - MrISMAIL ZABIULLA.>,
#  <Phone 9850356948 - MrMUKESH.>,
#  <Phone 9850356787 - MrSITA RAM..>,
#  <Phone 9850356573 - MrANUSHAKRISHNAN>,
#  <Phone 9850356013 - MrLOKESHM M>,
#  <Phone 9850355970 - MrRAM JI LAL.KUMAWAT>,
#  <Phone 9850355794 - MrRAKESH KUMAR.>,
#  <Phone 9850355777 - MsYASHODA..>,
#  <Phone 9850355129 - MrARSHADM.>,
#  <Phone 9850355103 - sUSHA.JOYA>,
#  <Phone 9850355046 - SURAJ MAL.>,
#  <Phone 9850354792 - SHAMEEM.>,
#  <Phone 9850354395 - PINKESH SANGOI>,
#  <Phone 9850354373 - SHASHANK P TATEWAR>,
#  <Phone 9850354291 - MAHESH JOSHI>,
#  <Phone 9850354280 - MANISH T URKUDE>,
# ...

# %%
[db.session.add(phone) for phone in phones]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
db.session.commit()

# %%
Phone.query.count()
# Out:
# 3145721

# %%
Phone.query.limit(10).first().number
# Out:
# 9850358213

# %%
type(Phone.query.limit(10).first().number)
# Out:
# int

# %%
Phone.query.filter_by(number = 1234567890).first()

# %%
db.sessionWordList.query.filter_by(word = "").first()
# Out:
# [Word<>]
